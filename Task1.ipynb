# %%
# Imports 
import numpy as np
import random
from datetime import datetime

# %%
# Parameters
n_cities = 20

n_population = 20

mutation_rate = 0.6

# %%
# Generating a list of coordenades representing each city
coordinates_list = [[x,y] for x,y in zip(np.random.randint(0,100,n_cities),np.random.randint(0,100,n_cities))]
names_list = np.array(['Berlin', 'London', 'Moscow', 'Barcelona', 'Rome', 'Paris', 'Vienna', 'Munich', 'Istanbul', 'Kyiv', 'Bucharest', 'Minsk', 'Warsaw', 'Budapest', 'Milan', 'Prague', 'Sofia', 'Birmingham', 'Brussels', 'Amsterdam'])
cities_dict = { x:y for x,y in zip(names_list,coordinates_list)}

# Function to compute the distance between two points
def compute_city_distance_coordinates(a,b):
    return ((a[0]-b[0])**2+(a[1]-b[1])**2)**0.5

def compute_city_distance_names(city_a, city_b, cities_dict):
    return compute_city_distance_coordinates(cities_dict[city_a], cities_dict[city_b])

cities_dict
# Out:
# {'Berlin': [37, 7],
#  'London': [96, 25],
#  'Moscow': [45, 79],
#  'Barcelona': [31, 57],
#  'Rome': [38, 45],
#  'Paris': [60, 47],
#  'Vienna': [15, 16],
#  'Munich': [33, 52],
#  'Istanbul': [50, 98],
#  'Kyiv': [79, 18],
#  'Bucharest': [24, 8],
#  'Minsk': [96, 13],
#  'Warsaw': [86, 36],
#  'Budapest': [83, 48],
#  'Milan': [95, 3],
#  'Prague': [17, 63],
#  'Sofia': [56, 84],
#  'Birmingham': [45, 83],
#  'Brussels': [97, 88],
#  'Amsterdam': [32, 29]}

# %%
# First step: Create the first population set
def genesis(city_list, n_population):

    population_set = []
    for i in range(n_population):
        #Randomly generating a new solution
        sol_i = city_list[np.random.choice(list(range(n_cities)), n_cities, replace=False)]
        population_set.append(sol_i)
    return np.array(population_set)

population_set = genesis(names_list, n_population)
population_set
# Out:
# array([['Vienna', 'Berlin', 'Prague', 'Bucharest', 'Rome', 'Istanbul',
#         'Brussels', 'Budapest', 'Minsk', 'London', 'Birmingham', 'Sofia',
#         'Paris', 'Warsaw', 'Moscow', 'Barcelona', 'Kyiv', 'Amsterdam',
#         'Milan', 'Munich'],
#        ['Rome', 'Berlin', 'Birmingham', 'Warsaw', 'Prague', 'Barcelona',
#         'Istanbul', 'Bucharest', 'Milan', 'Munich', 'Brussels', 'Paris',
#         'Amsterdam', 'Vienna', 'Budapest', 'Moscow', 'London', 'Kyiv',
#         'Minsk', 'Sofia'],
#        ['Prague', 'Sofia', 'Budapest', 'Minsk', 'Warsaw', 'Barcelona',
#         'Rome', 'Vienna', 'London', 'Moscow', 'Berlin', 'Bucharest',
#         'Brussels', 'Amsterdam', 'Paris', 'Kyiv', 'Istanbul',
#         'Birmingham', 'Milan', 'Munich'],
#        ['Amsterdam', 'Sofia', 'Prague', 'Vienna', 'Barcelona',
#         'Birmingham', 'Minsk', 'Istanbul', 'Bucharest', 'Kyiv', 'Rome',
#         'Milan', 'Brussels', 'Munich', 'Paris', 'Moscow', 'London',
#         'Budapest', 'Berlin', 'Warsaw'],
#        ['Milan', 'Minsk', 'Moscow', 'London', 'Istanbul', 'Vienna',
#         'Bucharest', 'Budapest', 'Munich', 'Sofia', 'Rome', 'Warsaw',
#         'Prague', 'Kyiv', 'Birmingham', 'Brussels', 'Amsterdam',
#         'Barcelona', 'Berlin', 'Paris'],
#        ['Amsterdam', 'London', 'Munich', 'Rome', 'Moscow', 'Minsk',
#         'Brussels', 'Birmingham', 'Prague', 'Budapest', 'Barcelona',
#         'Berlin', 'Sofia', 'Warsaw', 'Milan', 'Istanbul', 'Kyiv',
#         'Paris', 'Bucharest', 'Vienna'],
#        ['Sofia', 'Amsterdam', 'Milan', 'Rome', 'Warsaw', 'London',
#         'Moscow', 'Istanbul', 'Minsk', 'Bucharest', 'Birmingham',
#         'Brussels', 'Munich', 'Vienna', 'Kyiv', 'Berlin', 'Budapest',
#         'Paris', 'Barcelona', 'Prague'],
#        ['Vienna', 'Kyiv', 'Budapest', 'Moscow', 'Brussels', 'Prague',
#         'Milan', 'Sofia', 'Bucharest', 'Munich', 'Rome', 'Birmingham',
#         'Barcelona', 'Paris', 'Amsterdam', 'London', 'Warsaw', 'Berlin',
#         'Istanbul', 'Minsk'],
#        ['London', 'Amsterdam', 'Birmingham', 'Berlin', 'Bucharest',
#         'Vienna', 'Budapest', 'Barcelona', 'Kyiv', 'Moscow', 'Milan',
#         'Brussels', 'Sofia', 'Minsk', 'Istanbul', 'Warsaw', 'Rome',
#         'Prague', 'Munich', 'Paris'],
#        ['Amsterdam', 'Sofia', 'Berlin', 'Prague', 'Milan', 'Rome',
#         'Barcelona', 'Vienna', 'Kyiv', 'Birmingham', 'Paris', 'Budapest',
#         'Munich', 'Istanbul', 'London', 'Bucharest', 'Minsk', 'Brussels',
#         'Moscow', 'Warsaw'],
#        ['Rome', 'Vienna', 'Barcelona', 'Milan', 'Budapest', 'Munich',
#         'Istanbul', 'Moscow', 'Warsaw', 'Amsterdam', 'Kyiv', 'Paris',
#         'Prague', 'London', 'Birmingham', 'Bucharest', 'Brussels',
#         'Berlin', 'Minsk', 'Sofia'],
#        ['London', 'Budapest', 'Paris', 'Sofia', 'Milan', 'Amsterdam',
#         'Brussels', 'Kyiv', 'Warsaw', 'Vienna', 'Munich', 'Prague',
#         'Moscow', 'Barcelona', 'Istanbul', 'Rome', 'Berlin', 'Bucharest',
#         'Minsk', 'Birmingham'],
#        ['Budapest', 'Munich', 'Birmingham', 'Amsterdam', 'London',
#         'Rome', 'Moscow', 'Paris', 'Istanbul', 'Barcelona', 'Sofia',
#         'Bucharest', 'Vienna', 'Milan', 'Prague', 'Minsk', 'Berlin',
#         'Brussels', 'Kyiv', 'Warsaw'],
#        ['Berlin', 'Kyiv', 'Budapest', 'Moscow', 'Warsaw', 'Amsterdam',
#         'Brussels', 'Paris', 'London', 'Minsk', 'Barcelona', 'Vienna',
#         'Prague', 'Sofia', 'Bucharest', 'Birmingham', 'Milan', 'Munich',
#         'Istanbul', 'Rome'],
#        ['Milan', 'Prague', 'Berlin', 'Brussels', 'Budapest', 'London',
#         'Munich', 'Barcelona', 'Paris', 'Sofia', 'Istanbul',
#         'Birmingham', 'Amsterdam', 'Warsaw', 'Minsk', 'Rome', 'Moscow',
#         'Vienna', 'Bucharest', 'Kyiv'],
#        ['Amsterdam', 'Paris', 'Munich', 'Minsk', 'Moscow', 'Warsaw',
#         'Vienna', 'Milan', 'Birmingham', 'London', 'Bucharest',
#         'Budapest', 'Rome', 'Berlin', 'Barcelona', 'Kyiv', 'Brussels',
#         'Istanbul', 'Sofia', 'Prague'],
#        ['London', 'Birmingham', 'Minsk', 'Brussels', 'Vienna',
#         'Amsterdam', 'Bucharest', 'Prague', 'Warsaw', 'Rome', 'Munich',
#         'Milan', 'Kyiv', 'Sofia', 'Istanbul', 'Berlin', 'Barcelona',
#         'Paris', 'Moscow', 'Budapest'],
#        ['Birmingham', 'Minsk', 'Budapest', 'Prague', 'Moscow', 'Kyiv',
#         'Warsaw', 'Barcelona', 'Munich', 'Paris', 'Berlin', 'Vienna',
#         'Bucharest', 'Brussels', 'London', 'Istanbul', 'Amsterdam',
#         'Rome', 'Sofia', 'Milan'],
#        ['Prague', 'Budapest', 'Milan', 'Minsk', 'Berlin', 'Birmingham',
#         'Warsaw', 'Barcelona', 'Moscow', 'Brussels', 'Munich',
#         'Amsterdam', 'London', 'Sofia', 'Istanbul', 'Rome', 'Kyiv',
#         'Paris', 'Vienna', 'Bucharest'],
#        ['Rome', 'Brussels', 'Budapest', 'Istanbul', 'Moscow', 'Milan',
#         'Barcelona', 'London', 'Paris', 'Warsaw', 'Prague', 'Amsterdam',
#         'Bucharest', 'Sofia', 'Minsk', 'Birmingham', 'Munich', 'Vienna',
#         'Kyiv', 'Berlin']], dtype='<U10')

# %%
def fitness_eval(city_list, cities_dict):
    total = 0
    for i in range(n_cities-1):
        a = city_list[i]
        b = city_list[i+1]
        total += compute_city_distance_names(a,b, cities_dict)
    return total

# %%
def get_all_fitnes(population_set, cities_dict):
    fitnes_list = np.zeros(n_population)

    #Looping over all solutions computing the fitness for each solution
    for i in  range(n_population):
        fitnes_list[i] = fitness_eval(population_set[i], cities_dict)

    return fitnes_list

fitnes_list = get_all_fitnes(population_set,cities_dict)
fitnes_list
# Out:
# array([ 868.85923696, 1054.61119745, 1041.05722918, 1118.12839195,
#        1096.4576581 , 1051.98020028, 1007.21374034, 1060.84223034,
#        1071.17225405, 1144.13571977, 1165.54934931,  925.20343484,
#        1087.58131357, 1084.72365257,  874.08474297, 1124.48290762,
#        1022.2439588 ,  965.53830694,  912.00075483, 1077.75255917])

# %%
def progenitor_selection(population_set,fitnes_list):
    total_fit = fitnes_list.sum()
    prob_list = (total_fit/fitnes_list)
    prob_list = prob_list/prob_list.sum()
    
    #Notice there is the chance that a progenitor. mates with oneself
    progenitor_list_a = np.random.choice(list(range(len(population_set))), len(population_set),p=prob_list, replace=True)
    progenitor_list_b = np.random.choice(list(range(len(population_set))), len(population_set),p=prob_list, replace=True)
    
    progenitor_list_a = population_set[progenitor_list_a]
    progenitor_list_b = population_set[progenitor_list_b]
    
    
    return np.array([progenitor_list_a,progenitor_list_b])


progenitor_list = progenitor_selection(population_set,fitnes_list)
progenitor_list[0][2]
# Out:
# array(['Prague', 'Sofia', 'Budapest', 'Minsk', 'Warsaw', 'Barcelona',
#        'Rome', 'Vienna', 'London', 'Moscow', 'Berlin', 'Bucharest',
#        'Brussels', 'Amsterdam', 'Paris', 'Kyiv', 'Istanbul', 'Birmingham',
#        'Milan', 'Munich'], dtype='<U10')

# %%
def mate_progenitors(prog_a, prog_b):
    offspring = prog_a[0:5]

    for city in prog_b:

        if not city in offspring:
            offspring = np.concatenate((offspring,[city]))

    return offspring
            
    
    
def mate_population(progenitor_list):
    new_population_set = []
    for i in range(progenitor_list.shape[1]):
        prog_a, prog_b = progenitor_list[0][i], progenitor_list[1][i]
        offspring = mate_progenitors(prog_a, prog_b)
        new_population_set.append(offspring)
        
    return new_population_set

new_population_set = mate_population(progenitor_list)
new_population_set[0]
# Out:
# array(['London', 'Birmingham', 'Minsk', 'Brussels', 'Vienna', 'Amsterdam',
#        'Sofia', 'Berlin', 'Prague', 'Milan', 'Rome', 'Barcelona', 'Kyiv',
#        'Paris', 'Budapest', 'Munich', 'Istanbul', 'Bucharest', 'Moscow',
#        'Warsaw'], dtype='<U10')

# %%
def mutate_offspring(offspring):
    for q in range(int(n_cities*mutation_rate)):
        a = np.random.randint(0,n_cities)
        b = np.random.randint(0,n_cities)

        offspring[a], offspring[b] = offspring[b], offspring[a]

    return offspring
    
    
def mutate_population(new_population_set):
    mutated_pop = []
    for offspring in new_population_set:
        mutated_pop.append(mutate_offspring(offspring))
    return mutated_pop

mutated_pop = mutate_population(new_population_set)
mutated_pop[0]
# Out:
# array(['Rome', 'Moscow', 'Birmingham', 'Bucharest', 'Vienna', 'Amsterdam',
#        'Sofia', 'Warsaw', 'Prague', 'Milan', 'Istanbul', 'London', 'Kyiv',
#        'Paris', 'Budapest', 'Berlin', 'Minsk', 'Brussels', 'Barcelona',
#        'Munich'], dtype='<U10')

# %%
best_solution = [-1,np.inf,np.array([])]
for i in range(10000):
    if i%50==0: print(i, best_solution[1], fitnes_list.mean(), datetime.now().strftime("%d/%m/%y %H:%M"))
    fitnes_list = get_all_fitnes(mutated_pop,cities_dict)
    
    #Saving the best solution
    if fitnes_list.min() < best_solution[1]:
        best_solution[0] = i
        best_solution[1] = fitnes_list.min()
        best_solution[2] = np.array(mutated_pop)[fitnes_list.min() == fitnes_list]
    
    progenitor_list = progenitor_selection(population_set,fitnes_list)
    new_population_set = mate_population(progenitor_list)
    
    mutated_pop = mutate_population(new_population_set)
# Out:
# 0 inf 1037.6809419516737 08/10/23 22:52
# 50 591.071308933694 996.7364257097252 08/10/23 22:52
# 100 591.071308933694 1024.1456037685145 08/10/23 22:52
# 150 591.071308933694 1022.7641887872744 08/10/23 22:52
# 200 591.071308933694 1010.5810167350344 08/10/23 22:52
# 250 591.071308933694 1028.6883629674514 08/10/23 22:52
# 300 591.071308933694 1003.5993181046717 08/10/23 22:52
